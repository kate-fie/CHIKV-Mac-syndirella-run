# %%
import pandas as pd

# %%
df = pd.read_pickle('../WXVLITNXXROEMR-UHFFFAOYSA-N_T7iaYY_to_hippo.pkl.gz')
df
# Out:
#                     base_compound_smiles  \
# 0   CCc1nc(NC(=O)c2ccnc(NC3CC=CC3)c2)no1
# 1   CCc1nc(NC(=O)c2ccnc(NC3CC=CC3)c2)no1
# 2   CCc1nc(NC(=O)c2ccnc(NC3CC=CC3)c2)no1
# 3   CCc1nc(NC(=O)c2ccnc(NC3CC=CC3)c2)no1
# 4   CCc1nc(NC(=O)c2ccnc(NC3CC=CC3)c2)no1
# 5   CCc1nc(NC(=O)c2ccnc(NC3CC=CC3)c2)no1
# 6   CCc1nc(NC(=O)c2ccnc(NC3CC=CC3)c2)no1
# 7   CCc1nc(NC(=O)c2ccnc(NC3CC=CC3)c2)no1
# 8   CCc1nc(NC(=O)c2ccnc(NC3CC=CC3)c2)no1
# 9   CCc1nc(NC(=O)c2ccnc(NC3CC=CC3)c2)no1
# 10  CCc1nc(NC(=O)c2ccnc(NC3CC=CC3)c2)no1
#
#                                            1_reaction             1_r1_smiles  \
# 0   Buchwald-Hartwig_amidation_with_amide-like_nuc...           CCc1nc(Br)no1
# 1   Buchwald-Hartwig_amidation_with_amide-like_nuc...        Brc1noc(C2CC2)n1
# 2   Buchwald-Hartwig_amidation_with_amide-like_nuc...        CC(C)c1nc(Br)no1
# 3   Buchwald-Hartwig_amidation_with_amide-like_nuc...          CCCc1nc(Br)no1
# ...
