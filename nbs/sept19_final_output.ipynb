# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/kate_fieseler/PycharmProjects/CHIKV-Mac-syndirella-run/sept9_syndirella_final_output.csv')
df1 = pd.read_csv('/Users/kate_fieseler/PycharmProjects/CHIKV-Mac-syndirella-run/sept16_restart_outputs_20_1012.csv')
df = pd.concat([df,df1])
# save
#df.to_csv('../sept23_syndirella_final_output_all.csv', index=False)
df
# Out:
#                   1_r1_smiles                      1_r2_smiles  \
# 0               NC1CCC(=O)NC1       NC(=O)c1ccc(C(=O)O)c(Cl)c1
# 1                         NaN                              NaN
# 2                         NaN                              NaN
# 3                         NaN                              NaN
# 4                   Nc1ccccc1  COC(=O)c1cccc2c(C(=O)O)c[nH]c12
# ..                        ...                              ...
# 4            NC1CCCCC12CCCCC2                       COCC(=O)Cl
# 5                   Nc1ccccc1  COC(=O)c1cccc2c(C(=O)O)c[nH]c12
# 6               O=C(O)c1ccco1                 NC(=O)N1CCNCC1Cl
# 7                       OCCCl                      NNCc1cccnc1
# 8   O=Cc1nn(CC(=O)O)c2ccccc12                              CNC
#
#                               1_reaction  \
# 0                              Amidation
# 1                                    NaN
# 2                                    NaN
# ...

# %%
inchis = ['QZVYQICELPCZOV-UHFFFAOYSA-N', 'DETJXFSIQJPJAJ-UHFFFAOYSA-N']
df[df['inchi_key'].isin(inchis)]
# Out:
#                     1_r1_smiles      1_r2_smiles               1_reaction  \
# 44           Oc1cc2c(cc1Br)OCO2  OB(O)c1ccn[nH]1  Sp2-sp2_Suzuki_coupling
# 266  Cc1c[nH]c2ncc(C(=O)O)c-2c1               CO  Steglich_esterification
#
#     2_r1_smiles 2_r2_smiles 2_reaction 3_r1_smiles 3_reaction 4_r1_smiles  \
# 44          NaN         NaN        NaN         NaN        NaN         NaN
# 266         NaN         NaN        NaN         NaN        NaN         NaN
#
#     4_r2_smiles  ...                                           template  \
# 44          NaN  ...  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...
# 266         NaN  ...  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...
#
#        time                                           to_hippo  \
# 44   1031.0  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac/DE...
# 266   842.0  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac/QZ...
#
#     total_num_products_enumstereo total_num_unique_products hit1_short  \
# ...

# %%
# only get to_hippos
df1 = df[df['to_hippo'] != None]
df = df.dropna(subset=['to_hippo'])
df
# Out:
#                 1_r1_smiles                      1_r2_smiles  \
# 0             NC1CCC(=O)NC1       NC(=O)c1ccc(C(=O)O)c(Cl)c1
# 4                 Nc1ccccc1  COC(=O)c1cccc2c(C(=O)O)c[nH]c12
# 8       O=C(O)COc1cccc(F)c1                   CNCc1cccc(O)n1
# 10           CNCc1ccc(O)nc1                CCOc1ncccc1C(=O)O
# 14               NC1CCCC1CO            Clc1c(I)ccc2[nH]cnc12
# ..                      ...                              ...
# 348      Cc1ccncc1NC(=O)CCl            Cc1[nH][nH]c(=O)c1CCO
# 1    COC[C:1](=[O:2])[OH:3]                 NC1CCCCC12CCCCC2
# 2      O=C(c1ccco1)N1CCNCC1                     CCc1nc(N)no1
# 4          NC1CCCCC12CCCCC2                       COCC(=O)Cl
# 7                     OCCCl                      NNCc1cccnc1
#
#                                1_reaction  \
# 0                               Amidation
# 4                               Amidation
# 8                               Amidation
# 10                              Amidation
# ...

# %%
df[df['inchi_key']=='NEBUHSIGJIREQH-UHFFFAOYSA-N']
# Out:
#               1_r1_smiles       1_r2_smiles  \
# 1  COC[C:1](=[O:2])[OH:3]  NC1CCCCC12CCCCC2
# 4        NC1CCCCC12CCCCC2        COCC(=O)Cl
#
#                           1_reaction 2_r1_smiles 2_r2_smiles 2_reaction  \
# 1                          Amidation         NaN         NaN        NaN
# 4  Amide_Schotten-Baumann_with_amine         NaN         NaN        NaN
#
#   3_r1_smiles 3_reaction 4_r1_smiles 4_r2_smiles  ...  \
# 1         NaN        NaN         NaN         NaN  ...
# 4         NaN        NaN         NaN         NaN  ...
#
#                                             template time  \
# 1  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  NaN
# 4  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  NaN
#
#                                             to_hippo  \
# 1  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac/se...
# 4  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac/se...
#
#   total_num_products_enumstereo total_num_unique_products hit1_short  \
# ...

# %%
# drop inchi key duplicates, keeping second
df = df.drop_duplicates(subset=['inchi_key', '1_reaction'], keep='last')
df
# Out:
#                 1_r1_smiles                      1_r2_smiles  \
# 0             NC1CCC(=O)NC1       NC(=O)c1ccc(C(=O)O)c(Cl)c1
# 4                 Nc1ccccc1  COC(=O)c1cccc2c(C(=O)O)c[nH]c12
# 8       O=C(O)COc1cccc(F)c1                   CNCc1cccc(O)n1
# 10           CNCc1ccc(O)nc1                CCOc1ncccc1C(=O)O
# 14               NC1CCCC1CO            Clc1c(I)ccc2[nH]cnc12
# ..                      ...                              ...
# 348      Cc1ccncc1NC(=O)CCl            Cc1[nH][nH]c(=O)c1CCO
# 1    COC[C:1](=[O:2])[OH:3]                 NC1CCCCC12CCCCC2
# 2      O=C(c1ccco1)N1CCNCC1                     CCc1nc(N)no1
# 4          NC1CCCCC12CCCCC2                       COCC(=O)Cl
# 7                     OCCCl                      NNCc1cccnc1
#
#                                1_reaction  \
# 0                               Amidation
# 4                               Amidation
# 8                               Amidation
# 10                              Amidation
# ...

# %%
# remove any ones with errors
df = df[df['error_type'].isna()]
df
# Out:
#                 1_r1_smiles                      1_r2_smiles  \
# 0             NC1CCC(=O)NC1       NC(=O)c1ccc(C(=O)O)c(Cl)c1
# 4                 Nc1ccccc1  COC(=O)c1cccc2c(C(=O)O)c[nH]c12
# 8       O=C(O)COc1cccc(F)c1                   CNCc1cccc(O)n1
# 10           CNCc1ccc(O)nc1                CCOc1ncccc1C(=O)O
# 14               NC1CCCC1CO            Clc1c(I)ccc2[nH]cnc12
# ..                      ...                              ...
# 347      CNCc1cccc(=O)[nH]1               CCOC(=O)c1cn[nH]c1
# 348      Cc1ccncc1NC(=O)CCl            Cc1[nH][nH]c(=O)c1CCO
# 1    COC[C:1](=[O:2])[OH:3]                 NC1CCCCC12CCCCC2
# 2      O=C(c1ccco1)N1CCNCC1                     CCc1nc(N)no1
# 4          NC1CCCCC12CCCCC2                       COCC(=O)Cl
#
#                                1_reaction  \
# 0                               Amidation
# 4                               Amidation
# 8                               Amidation
# 10                              Amidation
# ...

# %%
df = df[df['num_successful']>0]
df
# Out:
#                 1_r1_smiles                      1_r2_smiles  \
# 0             NC1CCC(=O)NC1       NC(=O)c1ccc(C(=O)O)c(Cl)c1
# 4                 Nc1ccccc1  COC(=O)c1cccc2c(C(=O)O)c[nH]c12
# 8       O=C(O)COc1cccc(F)c1                   CNCc1cccc(O)n1
# 10           CNCc1ccc(O)nc1                CCOc1ncccc1C(=O)O
# 14               NC1CCCC1CO            Clc1c(I)ccc2[nH]cnc12
# ..                      ...                              ...
# 347      CNCc1cccc(=O)[nH]1               CCOC(=O)c1cn[nH]c1
# 348      Cc1ccncc1NC(=O)CCl            Cc1[nH][nH]c(=O)c1CCO
# 1    COC[C:1](=[O:2])[OH:3]                 NC1CCCCC12CCCCC2
# 2      O=C(c1ccco1)N1CCNCC1                     CCc1nc(N)no1
# 4          NC1CCCCC12CCCCC2                       COCC(=O)Cl
#
#                                1_reaction  \
# 0                               Amidation
# 4                               Amidation
# 8                               Amidation
# 10                              Amidation
# ...

# %%
df.num_successful.sum()
# Out:
# 111536.0

# %%
df.to_csv('../sept23_syndirella_final_output_in_hippo.csv', index=False)

# %%
df.value_counts()
