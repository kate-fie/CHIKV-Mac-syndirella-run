# %%
import pandas as pd
import glob2

# %%
# Load the data
df = pd.read_csv('/Users/kate_fieseler/PycharmProjects/CHIKV-Mac-syndirella-run/sept9_syndirella_final_output.csv')
df
# Out:
#             1_r1_smiles                      1_r2_smiles  \
# 0         NC1CCC(=O)NC1       NC(=O)c1ccc(C(=O)O)c(Cl)c1
# 1                   NaN                              NaN
# 2                   NaN                              NaN
# 3                   NaN                              NaN
# 4             Nc1ccccc1  COC(=O)c1cccc2c(C(=O)O)c[nH]c12
# ..                  ...                              ...
# 347  CNCc1cccc(=O)[nH]1               CCOC(=O)c1cn[nH]c1
# 348  Cc1ccncc1NC(=O)CCl            Cc1[nH][nH]c(=O)c1CCO
# 349                 NaN                              NaN
# 350                 NaN                              NaN
# 351                 NaN                              NaN
#
#                                1_reaction  \
# 0                               Amidation
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                               Amidation
# ...

# %%
no_scaffold_found = [
    "IBNRYRKGRKRSMK-NSHDSACASA-N",
    "XNVDJLXZBJHKFV-UHFFFAOYSA-N",
    "SEEGEKKHDHBILT-UHFFFAOYSA-N",
    "WLFMTZKZYACXSW-UHFFFAOYSA-N",
    "UQJZJBUURJWCJN-UHFFFAOYSA-N",
    "RTRFWLCSCBITKB-UHFFFAOYSA-N",
    "NEBUHSIGJIREQH-LBPRGKRZSA-N"
]
redo = df[df['inchi_key'].isin(no_scaffold_found)]
inputs = redo['input_num'].tolist()

# %%
inputs
# Out:
# [277, 145, 314, 95, 146, 264, 270, 291]

# %%
# # Write the input numbers to a file
# with open('jobs_sept16_restart.txt', 'w') as f:
#     for item in inputs:
#         f.write(f'job{item}.sh\n')

# %%
# # edit job scripts to add 'sept16_restart' as another directory level to original output path
# jobs = ['/Users/kate_fieseler/PycharmProjects/CHIKV-Mac-syndirella-run/jobs/job277.sh',
#         '/Users/kate_fieseler/PycharmProjects/CHIKV-Mac-syndirella-run/jobs/job145.sh',
#         '/Users/kate_fieseler/PycharmProjects/CHIKV-Mac-syndirella-run/jobs/job314.sh',
#         '/Users/kate_fieseler/PycharmProjects/CHIKV-Mac-syndirella-run/jobs/job95.sh',
#         '/Users/kate_fieseler/PycharmProjects/CHIKV-Mac-syndirella-run/jobs/job146.sh',
#         '/Users/kate_fieseler/PycharmProjects/CHIKV-Mac-syndirella-run/jobs/job264.sh',
#         '/Users/kate_fieseler/PycharmProjects/CHIKV-Mac-syndirella-run/jobs/job270.sh',
#         '/Users/kate_fieseler/PycharmProjects/CHIKV-Mac-syndirella-run/jobs/job291.sh',]
# for job in jobs:
#     for item in inputs:
#         if str(item) in job:
#             print(item)
#             # new path for output
#             new_path = f'/Users/kate_fieseler/PycharmProjects/CHIKV-Mac-syndirella-run/jobs_sept16_restart/job{item}.sh'
#             with open(job, 'r') as f:
#                 lines = f.readlines()
#                 new_lines = []
#                 for line in lines:
#                     if 'OUTPUT' in line:
#                         line = line.replace('CHIKV-Mac', 'CHIKV-Mac/sept16_restart')
#                     new_lines.append(line)
#             # If you want to write to a new file, you can do:
#             with open(new_path, 'w') as new_file:
#                 for new_line in new_lines:
#                     new_file.write(new_line)

# %%
# looking at output csvs
csvs = glob2.glob('/Users/kate_fieseler/PycharmProjects/CHIKV-Mac-syndirella-run/csvs/*.csv')
df = pd.DataFrame()
for csv in csvs:
    temp = pd.read_csv(csv)
    df = pd.concat([df, temp])
df.reset_index(inplace=True, drop=True)
df
# Out:
#                                           smiles                    inchi_key  \
# 0               CNC(=O)c1cn(C)c2c(C(=O)NC)cccc12  UQJZJBUURJWCJN-UHFFFAOYSA-N
# 1                   COCC(=O)N[C@H]1CCCCC12CCCCC2  NEBUHSIGJIREQH-UHFFFAOYSA-N
# 2        CCc1nc(NC(=O)N2CCN(C(=O)c3ccco3)CC2)no1  XNVDJLXZBJHKFV-UHFFFAOYSA-N
# 3        CN(C)C(=O)Cn1nc(CNc2ccc(O)cc2)c2ccccc21  WLFMTZKZYACXSW-UHFFFAOYSA-N
# 4                   COCC(=O)N[C@H]1CCCCC12CCCCC2  NEBUHSIGJIREQH-UHFFFAOYSA-N
# 5        CNC(=O)c1cccc2c(C(=O)Nc3ccccc3)c[nH]c12  RTRFWLCSCBITKB-UHFFFAOYSA-N
# 6  NC(=O)N1CCN(C(=O)c2ccco2)C[C@H]1NC(=O)c1cscn1  IBNRYRKGRKRSMK-UHFFFAOYSA-N
# 7                                 OCCNNCc1cccnc1  SEEGEKKHDHBILT-UHFFFAOYSA-N
# 8        CN(C)C(=O)Cn1nc(CNc2ccc(O)cc2)c2ccccc21  WLFMTZKZYACXSW-UHFFFAOYSA-N
#
#    error_type                                      error_message  \
# 0  IndexError         single positional indexer is out-of-bounds
# ...

# %%
df.to_csv('/Users/kate_fieseler/PycharmProjects/CHIKV-Mac-syndirella-run/sept16_restart_outputs_20_1012.csv', index=False)
