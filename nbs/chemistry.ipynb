# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem, rdinchi

# %%
df = pd.read_csv('../sept9_syndirella_final_output.csv')
df.columns
# Out:
# Index(['1_r1_smiles', '1_r2_smiles', '1_reaction', '2_r1_smiles',
#        '2_r2_smiles', '2_reaction', '3_r1_smiles', '3_reaction', '4_r1_smiles',
#        '4_r2_smiles', '4_reaction', 'compound_set', 'date', 'error_message',
#        'error_type', 'hit1', 'hit2', 'inchi_key', 'input_num', 'num_placed',
#        'num_successful', 'route_uuid', 'smiles', 'template', 'time',
#        'to_hippo', 'total_num_products_enumstereo',
#        'total_num_unique_products', 'hit1_short', 'hit2_short', 'placed',
#        'datetime', 'num_steps'],
#       dtype='object')

# %%
car = df[df['num_steps'] > 0]
car = car[~car['error_type'].notna()]
car = car[['smiles', '1_r1_smiles', '1_r2_smiles', '1_reaction', '2_r1_smiles',
       '2_r2_smiles', '2_reaction', '3_r1_smiles', '3_reaction', '4_r1_smiles',
       '4_r2_smiles', '4_reaction', 'num_steps', 'hit1_short', 'hit2_short', 'inchi_key', 'compound_set', 'total_num_unique_products', 'total_num_products_enumstereo', 'num_placed', 'num_successful']]
car
# Out:
#                                           smiles          1_r1_smiles  \
# 0    NC(=O)c1ccc(C(=O)N[C@@H]2CCC(=O)NC2)c(Cl)c1        NC1CCC(=O)NC1
# 4        CNC(=O)c1cccc2c(C(=O)Nc3ccccc3)c[nH]c12            Nc1ccccc1
# 8             CN(Cc1cccc(O)n1)C(=O)COc1cccc(F)c1  O=C(O)COc1cccc(F)c1
# 10              CCOc1ncccc1C(=O)N(C)Cc1ccc(O)nc1       CNCc1ccc(O)nc1
# 14         OC[C@@H]1CCC[C@H]1Nc1ccc2[nH]cnc2c1Cl           NC1CCCC1CO
# ..                                           ...                  ...
# 342                 OCN1COc2ccc(-c3ccn[nH]3)cc21                 OCCl
# 344             CN(C)C(=O)CN(C=O)c1cc[nH]c(=O)c1                 O=CO
# 346                           COCC(=O)Nc1ccccc1N           Nc1ccccc1N
# 347          CN(Cc1cccc(=O)[nH]1)C(=O)c1cn[nH]c1   CNCc1cccc(=O)[nH]1
# 348         Cc1ccncc1NC(=O)Cn1[nH]c(=O)c(CCO)c1C   Cc1ccncc1NC(=O)CCl
#
#                          1_r2_smiles                            1_reaction  \
# ...

# %%
non_car = df[df['error_type'] == 'NoSynthesisRoute']
non_car = non_car[['smiles', 'hit1_short', 'hit2_short', 'inchi_key', 'compound_set', 'error_type']]
non_car
# Out:
#                                                 smiles hit1_short hit2_short  \
# 1    CN(C(=O)c1cn[nH]c1)[C@H]1C[C@H](O)NC[C@@H]1NC(...    cx0732a    cx0300a
# 3              C[C@H](c1ccc(N)nc1)c1nc(Cn2ccccc2=O)no1    cx1406a    cx0316a
# 5              Cn1nccc1C(=O)NC[C@@H]1CC[C@@]2(NCNN2)S1    cx0892a    cx0281a
# 9                              COCc1onc(C(N)=O)c1C(F)F    cx0404a    cx0394a
# 12              Nc1ccc(S(=O)(=O)Nn2cnc3c(Cl)cccc32)cc1    cx0289a    cx0894d
# ..                                                 ...        ...        ...
# 339                        C#Cc1c(C)nc(N)c(C)c1CC(N)=O    cx0553a    cx1454a
# 341                CNC(=O)c1cn(C)c2c(Cl)c3nc[nH]c3cc12    cx0894e    cx0270a
# 345           Nc1ccc(S(=O)(=O)Nc2[nH]c(N)c3ccccc23)cc1    cx0289a    cx1271d
# 349  COCC(=O)N[C@H]1CC[C@@H](O)C[C@]12CCC[C@H](c1cc...    cx0864a    cx0935a
# 351           Cn1cc(C(N)=O)c(CCc2nc(Cn3ccccc3=O)no2)n1    cx0394a    cx0316a
#
# ...

# %%
car.to_csv('sept10_syndirella_CHIKV_MAC_car_routes.csv', index=False)
non_car.to_csv('sept10_syndirella_CHIKV_MAC_no_car_routes.csv', index=False)

# %%
# update the car routes with the base compounds we have
df = pd.read_csv('../sept23_syndirella_final_output_all.csv')
df['flat_inchi'] = df['smiles'].apply(lambda x: rdinchi.InchiToInchiKey(rdinchi.MolToInchi(Chem.MolFromSmiles(Chem.MolToSmiles(Chem.MolFromSmiles(x), isomericSmiles=False)))[0]))
df
# Out:
#                    1_r1_smiles                      1_r2_smiles  \
# 0                NC1CCC(=O)NC1       NC(=O)c1ccc(C(=O)O)c(Cl)c1
# 1                          NaN                              NaN
# 2                          NaN                              NaN
# 3                          NaN                              NaN
# 4                    Nc1ccccc1  COC(=O)c1cccc2c(C(=O)O)c[nH]c12
# ..                         ...                              ...
# 356           NC1CCCCC12CCCCC2                       COCC(=O)Cl
# 357                  Nc1ccccc1  COC(=O)c1cccc2c(C(=O)O)c[nH]c12
# 358              O=C(O)c1ccco1                 NC(=O)N1CCNCC1Cl
# 359                      OCCCl                      NNCc1cccnc1
# 360  O=Cc1nn(CC(=O)O)c2ccccc12                              CNC
#
#                                1_reaction  \
# 0                               Amidation
# 1                                     NaN
# 2                                     NaN
# ...

# %%
# only get inchi keys found in HIPPO
inchis = ['WRQXFZOITXUYML-UHFFFAOYSA-N',
 'SCMCRGMETQKMMQ-UHFFFAOYSA-N',
 'WXVLITNXXROEMR-UHFFFAOYSA-N',
 'UGYMLSSIEIESGU-UHFFFAOYSA-N',
 'KRUZICJRZZZCFH-UHFFFAOYSA-N',
 'LKSJOAHCUYUSRB-UHFFFAOYSA-N',
 'OHSGHNZPVAYZHL-UHFFFAOYSA-N',
 'DGASNXVGKHJXGC-UHFFFAOYSA-N',
 'ALGNJYIWMHXFNH-UHFFFAOYSA-N',
 'ZJENMQHSGLZNHL-UHFFFAOYSA-N',
 'OYZLDUQCBJYBED-UHFFFAOYSA-N',
 'TYBDSUPMDPIPBB-UHFFFAOYSA-N',
 'JAHJLJNEYRGXQB-UHFFFAOYSA-N',
 'SMVDAYWKXWVCAN-UHFFFAOYSA-N',
 'FCGOSHSMTQLVEX-UHFFFAOYSA-N',
 'CTECJTBKOFPTMY-UHFFFAOYSA-N',
 'LKDGGWMXOHPRMI-UHFFFAOYSA-N',
 'GQXYNJMUNPQGML-UHFFFAOYSA-N',
 'WZMWLLZLOKQLRZ-UHFFFAOYSA-N',
 'RGWZNWCCBDMABV-UHFFFAOYSA-N',
 'JOXQXTUGOHUMII-UHFFFAOYSA-N',
 'LSBSLADJXDRYPT-UHFFFAOYSA-N',
 'VXOZIAXPIMEJPP-UHFFFAOYSA-N',
 'QZVYQICELPCZOV-UHFFFAOYSA-N',
 'KIULBMGWDSJTMM-UHFFFAOYSA-N',
 'MNLAWAQYKQVGLK-UHFFFAOYSA-N',
 'LCANJRPVBLCVAU-UHFFFAOYSA-N',
 'DZVXXHSUENHLJH-UHFFFAOYSA-N',
 'IMTCTUMLWQUKFC-UHFFFAOYSA-N',
 'OYAFCPFGSBONSE-UHFFFAOYSA-N',
 'GEKAQEZWMKZGCA-UHFFFAOYSA-N',
 'YHGCJJWAPVTIRQ-UHFFFAOYSA-N',
 'KKYCNGMNUUPLTM-UHFFFAOYSA-N',
 'NEMWMYMPRDCSAZ-UHFFFAOYSA-N',
 'XDUHPRMEDNEUSF-UHFFFAOYSA-N',
 'MMXSHBZOILNLPJ-UHFFFAOYSA-N',
 'FESSPJKVYVFJPA-UHFFFAOYSA-N',
 'YIIMVUSFSKUYCA-UHFFFAOYSA-N',
 'OULBTDXTVHQBAE-UHFFFAOYSA-N',
 'QQERROZMPKKQER-UHFFFAOYSA-N',
 'WHLDZOYDHAHKLT-UHFFFAOYSA-N',
 'SBEBTLKTHHBVAY-UHFFFAOYSA-N',
 'GXJARPZGKFADOS-UHFFFAOYSA-N',
 'GNFBAQJUTMHLTB-UHFFFAOYSA-N',
 'KFMQBLWKRFIPBE-UHFFFAOYSA-N',
 'WLFMTZKZYACXSW-UHFFFAOYSA-N',
 'OLQDFRKRSFBPML-UHFFFAOYSA-N',
 'RZIGAYKJCIITOG-UHFFFAOYSA-N',
 'QVSYFXSEJNFZKD-UHFFFAOYSA-N',
 'IMOYJNKITCRRFB-UHFFFAOYSA-N',
 'PPHADCGGEPSVTM-UHFFFAOYSA-N',
 'XQWKZXHQRAAZAF-UHFFFAOYSA-N',
 'QQBWHKPVEOERHW-UHFFFAOYSA-N',
 'RRJMGDPCLBVSAU-UHFFFAOYSA-N',
 'FCNMMRVSBYHGGR-UHFFFAOYSA-N',
 'CVNPYWIROGTFDL-UHFFFAOYSA-N',
 'NXHHOOOYMWASMZ-UHFFFAOYSA-N',
 'DETJXFSIQJPJAJ-UHFFFAOYSA-N',
 'TUFPTLPAEQNWJN-UHFFFAOYSA-N',
 'XXPRWRCNORVHSY-UHFFFAOYSA-N',
 'XMHJIXAUMMKGLT-UHFFFAOYSA-N',
 'JXRCCCJCUJURBQ-UHFFFAOYSA-N',
 'LXNXWBLKTWRVII-UHFFFAOYSA-N',
 'MIMRXPBJLOWRMN-UHFFFAOYSA-N',
 'WZOLBARQWWYVFM-UHFFFAOYSA-N',
 'FXMHNJCWYFUXEW-UHFFFAOYSA-N',
 'ARCUOSJFSRBOMH-UHFFFAOYSA-N',
 'GLWBHHUWZUOZOL-UHFFFAOYSA-N']
df = df[df['flat_inchi'].isin(inchis)]
len(inchis)
# Out:
# 68

# %%
len(df)
# Out:
# 76

# %%
# which inchis not found
not_found = list(set(inchis) - set(df['flat_inchi']))
len(not_found)
# Out:
# 0

# %%
df = df[~df['to_hippo'].isna()]
df
# Out:
#              1_r1_smiles                  1_r2_smiles  \
# 0          NC1CCC(=O)NC1   NC(=O)c1ccc(C(=O)O)c(Cl)c1
# 8    O=C(O)COc1cccc(F)c1               CNCc1cccc(O)n1
# 10        CNCc1ccc(O)nc1            CCOc1ncccc1C(=O)O
# 14            NC1CCCC1CO        Clc1c(I)ccc2[nH]cnc12
# 17          NCc1ccc(O)s1             CCOC(=O)c1ccnn1C
# ..                   ...                          ...
# 342                 OCCl            Clc1ccc2c(c1)NCO2
# 344                 O=CO  CN(C)C(=O)CNc1cc[nH]c(=O)c1
# 346           Nc1ccccc1N            COCC(=O)OC(C)(C)C
# 347   CNCc1cccc(=O)[nH]1           CCOC(=O)c1cn[nH]c1
# 348   Cc1ccncc1NC(=O)CCl        Cc1[nH][nH]c(=O)c1CCO
#
#                                1_reaction          2_r1_smiles  \
# 0                               Amidation                  NaN
# 8                               Amidation                  NaN
# 10                              Amidation                  NaN
# ...

# %%
df = df.drop_duplicates(subset=['flat_inchi', '1_reaction'], keep='last')
df
# Out:
#              1_r1_smiles                  1_r2_smiles  \
# 0          NC1CCC(=O)NC1   NC(=O)c1ccc(C(=O)O)c(Cl)c1
# 8    O=C(O)COc1cccc(F)c1               CNCc1cccc(O)n1
# 10        CNCc1ccc(O)nc1            CCOc1ncccc1C(=O)O
# 14            NC1CCCC1CO        Clc1c(I)ccc2[nH]cnc12
# 17          NCc1ccc(O)s1             CCOC(=O)c1ccnn1C
# ..                   ...                          ...
# 342                 OCCl            Clc1ccc2c(c1)NCO2
# 344                 O=CO  CN(C)C(=O)CNc1cc[nH]c(=O)c1
# 346           Nc1ccccc1N            COCC(=O)OC(C)(C)C
# 347   CNCc1cccc(=O)[nH]1           CCOC(=O)c1cn[nH]c1
# 348   Cc1ccncc1NC(=O)CCl        Cc1[nH][nH]c(=O)c1CCO
#
#                                1_reaction          2_r1_smiles  \
# 0                               Amidation                  NaN
# 8                               Amidation                  NaN
# 10                              Amidation                  NaN
# ...

# %%
not_found = list(set(inchis) - set(df['flat_inchi']))
len(not_found)
# Out:
# 0

# %%
# drop any fully NaN columns
df = df.dropna(axis=1, how='all')
df
# Out:
#              1_r1_smiles                  1_r2_smiles  \
# 0          NC1CCC(=O)NC1   NC(=O)c1ccc(C(=O)O)c(Cl)c1
# 8    O=C(O)COc1cccc(F)c1               CNCc1cccc(O)n1
# 10        CNCc1ccc(O)nc1            CCOc1ncccc1C(=O)O
# 14            NC1CCCC1CO        Clc1c(I)ccc2[nH]cnc12
# 17          NCc1ccc(O)s1             CCOC(=O)c1ccnn1C
# ..                   ...                          ...
# 342                 OCCl            Clc1ccc2c(c1)NCO2
# 344                 O=CO  CN(C)C(=O)CNc1cc[nH]c(=O)c1
# 346           Nc1ccccc1N            COCC(=O)OC(C)(C)C
# 347   CNCc1cccc(=O)[nH]1           CCOC(=O)c1cn[nH]c1
# 348   Cc1ccncc1NC(=O)CCl        Cc1[nH][nH]c(=O)c1CCO
#
#                                1_reaction          2_r1_smiles  \
# 0                               Amidation                  NaN
# 8                               Amidation                  NaN
# 10                              Amidation                  NaN
# ...

# %%
df[df['flat_inchi'] == 'WLFMTZKZYACXSW-UHFFFAOYSA-N']
df.to_csv('')
# Out:
#                    1_r1_smiles   1_r2_smiles           1_reaction  \
# 73   O=Cc1nn(CC(=O)O)c2ccccc12           CNC            Amidation
# 127  O=Cc1nn(CC(=O)O)c2ccccc12  Nc1ccc(O)cc1  Reductive_amination
#
#                              2_r1_smiles                    2_r2_smiles  \
# 73                          Nc1ccc(O)cc1  CN(C)C(=O)Cn1nc(C=O)c2ccccc21
# 127  O=C(O)Cn1nc(CNc2ccc(O)cc2)c2ccccc21                            CNC
#
#               2_reaction     compound_set        date  \
# 73   Reductive_amination  cx0935a-cx0312a  2024-09-04
# 127            Amidation  cx0312a-cx0935a  2024-09-04
#
#                                                 hit1  \
# 73   CHIKV_MacB-x0935_C_401_CHIKV_MacB-x0300+A+401+1
# 127  CHIKV_MacB-x0935_C_401_CHIKV_MacB-x0300+A+401+1
#
#                                                 hit2  ...    time  \
# 73   CHIKV_MacB-x0312_A_304_CHIKV_MacB-x0300+A+401+1  ...  1257.0
# 127  CHIKV_MacB-x0312_A_304_CHIKV_MacB-x0300+A+401+1  ...  2001.0
#
# ...

# %%
columns_to_drop = ['date',
                   'inchi_key',
                   'total_num_products_enumstereo',
                   'total_num_unique_products',
                   'placed',
                   'num_placed',
                   'num_successful',
                   'hit1',
                   'hit2',
                   'to_hippo',
                   'template',
                   'time']
df = df.drop(columns=columns_to_drop)
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#             1_r1_smiles                  1_r2_smiles  \
# 0         NC1CCC(=O)NC1   NC(=O)c1ccc(C(=O)O)c(Cl)c1
# 1   O=C(O)COc1cccc(F)c1               CNCc1cccc(O)n1
# 2        CNCc1ccc(O)nc1            CCOc1ncccc1C(=O)O
# 3            NC1CCCC1CO        Clc1c(I)ccc2[nH]cnc12
# 4          NCc1ccc(O)s1             CCOC(=O)c1ccnn1C
# ..                  ...                          ...
# 64                 OCCl            Clc1ccc2c(c1)NCO2
# 65                 O=CO  CN(C)C(=O)CNc1cc[nH]c(=O)c1
# 66           Nc1ccccc1N            COCC(=O)OC(C)(C)C
# 67   CNCc1cccc(=O)[nH]1           CCOC(=O)c1cn[nH]c1
# 68   Cc1ccncc1NC(=O)CCl        Cc1[nH][nH]c(=O)c1CCO
#
#                               1_reaction          2_r1_smiles  \
# 0                              Amidation                  NaN
# 1                              Amidation                  NaN
# 2                              Amidation                  NaN
# 3             Buchwald-Hartwig_amination                  NaN
# ...

# %%
df.to_csv('../sept23_syndirella_CHIKV_MAC_final_car_routes.csv', index=False)
