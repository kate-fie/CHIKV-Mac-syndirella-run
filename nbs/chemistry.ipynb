# %%
import pandas as pd

# %%
df = pd.read_csv('../sept9_syndirella_final_output.csv')
df
# Out:
#             1_r1_smiles                      1_r2_smiles  \
# 0         NC1CCC(=O)NC1       NC(=O)c1ccc(C(=O)O)c(Cl)c1
# 1                   NaN                              NaN
# 2                   NaN                              NaN
# 3                   NaN                              NaN
# 4             Nc1ccccc1  COC(=O)c1cccc2c(C(=O)O)c[nH]c12
# ..                  ...                              ...
# 345  CNCc1cccc(=O)[nH]1               CCOC(=O)c1cn[nH]c1
# 346  Cc1ccncc1NC(=O)CCl            Cc1[nH][nH]c(=O)c1CCO
# 347                 NaN                              NaN
# 348                 NaN                              NaN
# 349                 NaN                              NaN
#
#                                1_reaction  \
# 0                               Amidation
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                               Amidation
# ..                                    ...
# 345                       Ester_amidation
# 346  Nucleophilic_substitution_with_amine
# 347                                   NaN
# 348                                   NaN
# 349                                   NaN
#
#                                  2_r1_smiles 2_r2_smiles       2_reaction  \
# 0                                        NaN         NaN              NaN
# 1                                        NaN         NaN              NaN
# 2                                        NaN         NaN              NaN
# 3                                        NaN         NaN              NaN
# 4    COC(=O)c1cccc2c(C(=O)Nc3ccccc3)c[nH]c12          CN  Ester_amidation
# ..                                       ...         ...              ...
# 345                                      NaN         NaN              NaN
# 346                                      NaN         NaN              NaN
# 347                                      NaN         NaN              NaN
# 348                                      NaN         NaN              NaN
# 349                                      NaN         NaN              NaN
#
#     3_r1_smiles 3_reaction 4_r1_smiles 4_r2_smiles  ...  \
# 0           NaN        NaN         NaN         NaN  ...
# 1           NaN        NaN         NaN         NaN  ...
# 2           NaN        NaN         NaN         NaN  ...
# 3           NaN        NaN         NaN         NaN  ...
# 4           NaN        NaN         NaN         NaN  ...
# ..          ...        ...         ...         ...  ...
# 345         NaN        NaN         NaN         NaN  ...
# 346         NaN        NaN         NaN         NaN  ...
# 347         NaN        NaN         NaN         NaN  ...
# 348         NaN        NaN         NaN         NaN  ...
# 349         NaN        NaN         NaN         NaN  ...
#
#                                               template  time  \
# 0    /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1802
# 1    /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1740
# 2    /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1802
# 3    /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1734
# 4    /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1523
# ..                                                 ...   ...
# 345  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1900
# 346  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1800
# 347  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1026
# 348  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...   908
# 349  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1731
#
#                                               to_hippo  \
# 0    /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac/SM...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac/RT...
# ..                                                 ...
# 345  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac/ZJ...
# 346  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac/GQ...
# 347                                                NaN
# 348                                                NaN
# 349                                                NaN
#
#     total_num_products_enumstereo total_num_unique_products hit1_short  \
# 0                          2546.0                     994.0    cx1371a
# 1                             NaN                       NaN    cx0732a
# 2                             NaN                       NaN    cx0864a
# 3                             NaN                       NaN    cx1406a
# 4                         12100.0                   10600.0    cx0692a
# ..                            ...                       ...        ...
# 345                        5721.0                    3934.0    cx0732a
# 346                          81.0                      79.0    cx0317a
# 347                           NaN                       NaN    cx0864a
# 348                           NaN                       NaN    cx0394a
# 349                           NaN                       NaN    cx0394a
#
#     hit2_short placed             datetime  num_steps
# 0      cx0300a   True  2024-09-03 18:02:00          1
# 1      cx0300a  False  2024-09-03 17:40:00          0
# 2      cx1194a  False  2024-09-03 18:02:00          0
# 3      cx0316a  False  2024-09-03 17:34:00          0
# 4      cx0399b   True  2024-09-04 15:23:00          2
# ..         ...    ...                  ...        ...
# 345    cx1135a   True  2024-09-03 19:00:00          1
# 346    cx0305a   True  2024-09-03 18:00:00          1
# 347    cx0935a  False  2024-09-04 10:26:00          0
# 348    cx0839a  False  2024-09-04 09:08:00          0
# 349    cx0316a  False  2024-09-03 17:31:00          0
#
# [350 rows x 33 columns]

# %%
car = df[df['num_steps'] > 0]
car
# Out:
#              1_r1_smiles                      1_r2_smiles  \
# 0          NC1CCC(=O)NC1       NC(=O)c1ccc(C(=O)O)c(Cl)c1
# 4              Nc1ccccc1  COC(=O)c1cccc2c(C(=O)O)c[nH]c12
# 8    O=C(O)COc1cccc(F)c1                   CNCc1cccc(O)n1
# 10        CNCc1ccc(O)nc1                CCOc1ncccc1C(=O)O
# 14            NC1CCCC1CO            Clc1c(I)ccc2[nH]cnc12
# ..                   ...                              ...
# 340                 OCCl                Clc1ccc2c(c1)NCO2
# 342                 O=CO      CN(C)C(=O)CNc1cc[nH]c(=O)c1
# 344           Nc1ccccc1N                COCC(=O)OC(C)(C)C
# 345   CNCc1cccc(=O)[nH]1               CCOC(=O)c1cn[nH]c1
# 346   Cc1ccncc1NC(=O)CCl            Cc1[nH][nH]c(=O)c1CCO
#
#                                1_reaction  \
# 0                               Amidation
# 4                               Amidation
# 8                               Amidation
# 10                              Amidation
# 14             Buchwald-Hartwig_amination
# ..                                    ...
# 340  Nucleophilic_substitution_with_amine
# 342                             Amidation
# 344                       Ester_amidation
# 345                       Ester_amidation
# 346  Nucleophilic_substitution_with_amine
#
#                                  2_r1_smiles      2_r2_smiles  \
# 0                                        NaN              NaN
# 4    COC(=O)c1cccc2c(C(=O)Nc3ccccc3)c[nH]c12               CN
# 8                                        NaN              NaN
# 10                                       NaN              NaN
# 14                                       NaN              NaN
# ..                                       ...              ...
# 340                      OCN1COc2ccc(Cl)cc21  OB(O)c1ccn[nH]1
# 342                                      NaN              NaN
# 344                                      NaN              NaN
# 345                                      NaN              NaN
# 346                                      NaN              NaN
#
#                   2_reaction 3_r1_smiles 3_reaction 4_r1_smiles 4_r2_smiles  \
# 0                        NaN         NaN        NaN         NaN         NaN
# 4            Ester_amidation         NaN        NaN         NaN         NaN
# 8                        NaN         NaN        NaN         NaN         NaN
# 10                       NaN         NaN        NaN         NaN         NaN
# 14                       NaN         NaN        NaN         NaN         NaN
# ..                       ...         ...        ...         ...         ...
# 340  Sp2-sp2_Suzuki_coupling         NaN        NaN         NaN         NaN
# 342                      NaN         NaN        NaN         NaN         NaN
# 344                      NaN         NaN        NaN         NaN         NaN
# 345                      NaN         NaN        NaN         NaN         NaN
# 346                      NaN         NaN        NaN         NaN         NaN
#
#      ...                                           template  time  \
# 0    ...  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1802
# 4    ...  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1523
# 8    ...  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1007
# 10   ...  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  2056
# 14   ...  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1135
# ..   ...                                                ...   ...
# 340  ...  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1131
# 342  ...  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...   909
# 344  ...  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1112
# 345  ...  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1900
# 346  ...  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1800
#
#                                               to_hippo  \
# 0    /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac/SM...
# 4    /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac/RT...
# 8    /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac/MN...
# 10   /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac/FC...
# 14   /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac/WH...
# ..                                                 ...
# 340  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac/CV...
# 342  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac/KK...
# 344  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac/PP...
# 345  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac/ZJ...
# 346  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac/GQ...
#
#     total_num_products_enumstereo total_num_unique_products hit1_short  \
# 0                          2546.0                     994.0    cx1371a
# 4                         12100.0                   10600.0    cx0692a
# 8                          2300.0                    1343.0    cx1118a
# 10                         6954.0                    4319.0    cx0522a
# 14                         6588.0                     268.0    cx0406a
# ..                            ...                       ...        ...
# 340                       21561.0                   12326.0    cx0864d
# 342                         815.0                     609.0    cx1076a
# 344                     1589580.0                   20520.0    cx0692a
# 345                        5721.0                    3934.0    cx0732a
# 346                          81.0                      79.0    cx0317a
#
#     hit2_short placed             datetime  num_steps
# 0      cx0300a   True  2024-09-03 18:02:00          1
# 4      cx0399b   True  2024-09-04 15:23:00          2
# 8      cx0540a   True  2024-09-04 10:07:00          1
# 10     cx1118a   True  2024-09-03 20:56:00          1
# 14     cx0894a   True  2024-09-04 11:35:00          1
# ..         ...    ...                  ...        ...
# 340    cx0969b   True  2024-09-04 11:31:00          2
# 342    cx0721a   True  2024-09-04 09:09:00          1
# 344    cx1116a   True  2024-09-05 11:12:00          1
# 345    cx1135a   True  2024-09-03 19:00:00          1
# 346    cx0305a   True  2024-09-03 18:00:00          1
#
# [81 rows x 33 columns]

# %%
non_car = df[df['error_type'] == 'NoSynthesisRoute']
non_car = non_car[['smiles', 'hit1_short', 'hit2_short', 'inchi_key', 'compound_set', 'error_type']]
non_car
# Out:
#                                                 smiles hit1_short hit2_short  \
# 1    CN(C(=O)c1cn[nH]c1)[C@H]1C[C@H](O)NC[C@@H]1NC(...    cx0732a    cx0300a
# 3              C[C@H](c1ccc(N)nc1)c1nc(Cn2ccccc2=O)no1    cx1406a    cx0316a
# 5              Cn1nccc1C(=O)NC[C@@H]1CC[C@@]2(NCNN2)S1    cx0892a    cx0281a
# 9                              COCc1onc(C(N)=O)c1C(F)F    cx0404a    cx0394a
# 12              Nc1ccc(S(=O)(=O)Nn2cnc3c(Cl)cccc32)cc1    cx0289a    cx0894d
# ..                                                 ...        ...        ...
# 337                        C#Cc1c(C)nc(N)c(C)c1CC(N)=O    cx0553a    cx1454a
# 339                CNC(=O)c1cn(C)c2c(Cl)c3nc[nH]c3cc12    cx0894e    cx0270a
# 343           Nc1ccc(S(=O)(=O)Nc2[nH]c(N)c3ccccc23)cc1    cx0289a    cx1271d
# 347  COCC(=O)N[C@H]1CC[C@@H](O)C[C@]12CCC[C@H](c1cc...    cx0864a    cx0935a
# 349           Cn1cc(C(N)=O)c(CCc2nc(Cn3ccccc3=O)no2)n1    cx0394a    cx0316a
#
#                        inchi_key          compound_set        error_type
# 1    LDWRVYYEBGYWCU-DLOVCJGASA-N       cx0732a-cx0300a  NoSynthesisRoute
# 3    DEYCAJGWGSVJCX-SNVBAGLBSA-N       cx0316a-cx1406a  NoSynthesisRoute
# 5    ZNHLZZKVXUVQKY-KWQFWETISA-N  cx0892a-cx0281a_copy  NoSynthesisRoute
# 9    INXKNUPVWKJHJT-UHFFFAOYSA-N       cx0404a-cx0394a  NoSynthesisRoute
# 12   ZICDNRGAIBEXSM-UHFFFAOYSA-N       cx0894d-cx0289a  NoSynthesisRoute
# ..                           ...                   ...               ...
# 337  BMGQHBWGLDDFQB-UHFFFAOYSA-N       cx1454a-cx0553a  NoSynthesisRoute
# 339  WXNCMUCDEAHMII-UHFFFAOYSA-N       cx0270a-cx0894e  NoSynthesisRoute
# 343  OROZIPSUGMATNY-UHFFFAOYSA-N       cx0289a-cx1271d  NoSynthesisRoute
# 347  JOMKNPKJLUDQRQ-UICACZKSSA-N       cx0935a-cx0864a  NoSynthesisRoute
# 349  UOYWXIITSWPSHI-UHFFFAOYSA-N    CHIKVMac-DLS-DF004  NoSynthesisRoute
#
# [200 rows x 6 columns]

# %%
car.to_csv('sept10_syndirella_CHIKV_MAC_car_routes.csv', index=False)
non_car.to_csv('sept10_syndirella_CHIKV_MAC_no_car_routes.csv', index=False)
