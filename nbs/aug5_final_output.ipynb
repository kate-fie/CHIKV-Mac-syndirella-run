# %%
import pandas as pd
import os
import glob2
import re

# %%
def extract_last_number(my_string):
    # Use regex to find a sequence of digits at the end of the string (1-3 digits)
    match = re.search(r'(\d{1,3})$', my_string)
    if match:
        return int(match.group(1))
    else:
        return None  # No digits found

csvs = glob2.glob('/Users/kate_fieseler/PycharmProjects/CHIKV-Mac-syndirella-run/csv_output/csvs_aug5_0952/*.csv')
rows = []
final_df = None
for csv in csvs:
    df = pd.read_csv(csv)
    # add date and time and input
    date = os.path.basename(csv).split('_')[3]
    time = os.path.basename(csv).split('_')[4].split('.')[0]
    input_num = extract_last_number(os.path.basename(csv).split('_')[1])
    df['date'] = date
    df['time'] = time
    df['input_num'] = input_num
    if final_df is None:
        final_df = df
    else:
        # Align the columns of output_df and row_df
        combined_columns = final_df.columns.union(df.columns)
        final_df = final_df.reindex(columns=combined_columns)
        df = df.reindex(columns=combined_columns)
        final_df = pd.concat([final_df, df], ignore_index=True)

# %%
df = final_df
df
# Out:
#             1_r1_smiles                      1_r2_smiles  \
# 0         NC1CCC(=O)NC1       NC(=O)c1ccc(C(=O)O)c(Cl)c1
# 1                   NaN                              NaN
# 2                   NaN                              NaN
# 3                   NaN                              NaN
# 4             Nc1ccccc1  COC(=O)c1cccc2c(C(=O)O)c[nH]c12
# ..                  ...                              ...
# 345  CNCc1cccc(=O)[nH]1               CCOC(=O)c1cn[nH]c1
# 346  Cc1ccncc1NC(=O)CCl            Cc1[nH][nH]c(=O)c1CCO
# 347                 NaN                              NaN
# 348                 NaN                              NaN
# 349                 NaN                              NaN
#
#                                1_reaction  \
# 0                               Amidation
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                               Amidation
# ..                                    ...
# 345                       Ester_amidation
# 346  Nucleophilic_substitution_with_amine
# 347                                   NaN
# 348                                   NaN
# 349                                   NaN
#
#                                  2_r1_smiles 2_r2_smiles       2_reaction  \
# 0                                        NaN         NaN              NaN
# 1                                        NaN         NaN              NaN
# 2                                        NaN         NaN              NaN
# 3                                        NaN         NaN              NaN
# 4    COC(=O)c1cccc2c(C(=O)Nc3ccccc3)c[nH]c12          CN  Ester_amidation
# ..                                       ...         ...              ...
# 345                                      NaN         NaN              NaN
# 346                                      NaN         NaN              NaN
# 347                                      NaN         NaN              NaN
# 348                                      NaN         NaN              NaN
# 349                                      NaN         NaN              NaN
#
#     3_r1_smiles 3_reaction 4_r1_smiles 4_r2_smiles  ... input_num num_placed  \
# 0           NaN        NaN         NaN         NaN  ...        44      284.0
# 1           NaN        NaN         NaN         NaN  ...        30        NaN
# 2           NaN        NaN         NaN         NaN  ...        73        NaN
# 3           NaN        NaN         NaN         NaN  ...        18        NaN
# 4           NaN        NaN         NaN         NaN  ...       277    10000.0
# ..          ...        ...         ...         ...  ...       ...        ...
# 345         NaN        NaN         NaN         NaN  ...        29     2217.0
# 346         NaN        NaN         NaN         NaN  ...        58       44.0
# 347         NaN        NaN         NaN         NaN  ...       320        NaN
# 348         NaN        NaN         NaN         NaN  ...       165        NaN
# 349         NaN        NaN         NaN         NaN  ...        12        NaN
#
#     num_successful route_uuid  \
# 0            173.0     32fgo7
# 1              NaN        NaN
# 2              NaN        NaN
# 3              NaN        NaN
# 4           9780.0     6PQWWH
# ..             ...        ...
# 345         1356.0     ZzGYCp
# 346           31.0     STWk5f
# 347            NaN        NaN
# 348            NaN        NaN
# 349            NaN        NaN
#
#                                                 smiles  \
# 0          NC(=O)c1ccc(C(=O)N[C@@H]2CCC(=O)NC2)c(Cl)c1
# 1    CN(C(=O)c1cn[nH]c1)[C@H]1C[C@H](O)NC[C@@H]1NC(...
# 2                    Cc1cc2c(c(C)c1-c1cc[nH]n1)N(C)CO2
# 3              C[C@H](c1ccc(N)nc1)c1nc(Cn2ccccc2=O)no1
# 4              CNC(=O)c1cccc2c(C(=O)Nc3ccccc3)c[nH]c12
# ..                                                 ...
# 345                CN(Cc1cccc(=O)[nH]1)C(=O)c1cn[nH]c1
# 346               Cc1ccncc1NC(=O)Cn1[nH]c(=O)c(CCO)c1C
# 347  COCC(=O)N[C@H]1CC[C@@H](O)C[C@]12CCC[C@H](c1cc...
# 348                             CNc1cc(O)c2cccc(C)c2n1
# 349           Cn1cc(C(N)=O)c(CCc2nc(Cn3ccccc3=O)no2)n1
#
#                                               template  time  \
# 0    /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1802
# 1    /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1740
# 2    /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1802
# 3    /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1734
# 4    /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1523
# ..                                                 ...   ...
# 345  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1900
# 346  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1800
# 347  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1026
# 348  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  0908
# 349  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1731
#
#                                               to_hippo  \
# 0    /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac//S...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac//R...
# ..                                                 ...
# 345  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac//Z...
# 346  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac//G...
# 347                                                NaN
# 348                                                NaN
# 349                                                NaN
#
#      total_num_products_enumstereo  total_num_unique_products
# 0                           2546.0                      994.0
# 1                              NaN                        NaN
# 2                              NaN                        NaN
# 3                              NaN                        NaN
# 4                          12100.0                    10600.0
# ..                             ...                        ...
# 345                         5721.0                     3934.0
# 346                           81.0                       79.0
# 347                            NaN                        NaN
# 348                            NaN                        NaN
# 349                            NaN                        NaN
#
# [350 rows x 28 columns]

# %%
df.compound_set.value_counts()
# Out:
# compound_set
# CHIKVMac-DLS-DF003    2
# CHIKVMac-DLS-DF002    2
# cx1371a-cx0300a       1
# cx0399b-cx0270a       1
# cx0892a-cx0281a       1
#                      ..
# cx0543a-cx0316a       1
# CHIKVMac-DLS-JA005    1
# CHIKVMac-DLS-JA006    1
# cx1116a-cx0477a       1
# CHIKVMac-DLS-DF004    1
# Name: count, Length: 348, dtype: int64

# %%
df.input_num.value_counts()
# Out:
# input_num
# 11     2
# 10     2
# 44     1
# 270    1
# 20     1
#       ..
# 146    1
# 4      1
# 5      1
# 95     1
# 12     1
# Name: count, Length: 348, dtype: int64

# %%
df[df['input_num']==10]
# Out:
#            1_r1_smiles                1_r2_smiles 1_reaction 2_r1_smiles  \
# 310  Nc1cnc2[nH]ccc2c1  Cc1[nH][nH]c(=O)c1CC(=O)O  Amidation         NaN
# 311  Nc1cnc2[nH]ccc2c1  Cc1[nH][nH]c(=O)c1CC(=O)O  Amidation         NaN
#
#     2_r2_smiles 2_reaction 3_r1_smiles 3_reaction 4_r1_smiles 4_r2_smiles  \
# 310         NaN        NaN         NaN        NaN         NaN         NaN
# 311         NaN        NaN         NaN        NaN         NaN         NaN
#
#      ... input_num num_placed num_successful route_uuid  \
# 310  ...        10       96.0           81.0     Ndgh2a
# 311  ...        10       96.0           77.0     GDNfCh
#
#                                         smiles  \
# 310  Cc1[nH][nH]c(=O)c1CC(=O)Nc1cnc2[nH]ccc2c1
# 311  Cc1[nH][nH]c(=O)c1CC(=O)Nc1cnc2[nH]ccc2c1
#
#                                               template  time  \
# 310  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1738
# 311  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1738
#
#                                               to_hippo  \
# 310  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac//O...
# 311  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac//O...
#
#      total_num_products_enumstereo  total_num_unique_products
# 310                          129.0                      126.0
# 311                          129.0                      126.0
#
# [2 rows x 28 columns]

# %%
df[df['input_num'] == 11]
# Out:
#     1_r1_smiles 1_r2_smiles 1_reaction 2_r1_smiles 2_r2_smiles 2_reaction  \
# 108         NaN         NaN        NaN         NaN         NaN        NaN
# 109         NaN         NaN        NaN         NaN         NaN        NaN
#
#     3_r1_smiles 3_reaction 4_r1_smiles 4_r2_smiles  ... input_num num_placed  \
# 108         NaN        NaN         NaN         NaN  ...        11        NaN
# 109         NaN        NaN         NaN         NaN  ...        11        NaN
#
#     num_successful route_uuid                            smiles  \
# 108            NaN        NaN  Nc1ccc(-c2nc(Cn3ccccc3=O)no2)cn1
# 109            NaN        NaN  Nc1ccc(-c2nc(Cn3ccccc3=O)no2)cn1
#
#                                               template  time to_hippo  \
# 108  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1731      NaN
# 109  /opt/xchem-fragalysis-2/kfieseler/CHIKV-Mac-sy...  1731      NaN
#
#      total_num_products_enumstereo  total_num_unique_products
# 108                            NaN                        NaN
# 109                            NaN                        NaN
#
# [2 rows x 28 columns]

# %%
# remove input num duplicates
df = df.drop_duplicates(subset=['input_num'])
len(df)
# Out:
# 348

# %%
# what ints from 0 to 353 are not included
missing = set(range(354)) - set(list(df.input_num))
missing
# Out:
# {40, 87, 283, 302, 304, 329}

# %%
# start these
with open('/Users/kate_fieseler/PycharmProjects/CHIKV-Mac-syndirella-run/jobs_6_missing.txt', 'w') as f:
    for i in missing:
        f.write(f'job{i}.sh\n')
